# %%
# !nvidia-smi

# !pip install yfinance
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

yf.Ticker('AAPL').info

tickers = ['AAPL', 'MSFT', 'IBM']

infos =[]

for i in tickers:
  infos.append(yf.Ticker(i).info)

fundamentals = ['dividendYield','marketCap','beta','forwardPE']
df = pd.DataFrame(infos)

df = df.set_index('symbol')
df[df.columns[df.columns.isin(fundamentals)]]

###### Ok let's pull for dow jones now
df2 = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1]
df2

tickers = df2.Symbol.to_list()
tickers

infos = []

for i in tickers: 
  infos.append(yf.Ticker(i).info)

df2 = pd.DataFrame(infos)
df2 = df2.set_index('symbol')
df2
# with each column now let's examine what's interesting
# df2['ebitdaMargins'].nlargest(5)
# Out:
# zsh:1: command not found: nvidia-smi
# ...
#      |████████████████████████████████| 4.7 MB 2.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... /^C
# anceled
# ERROR: Operation cancelled by user
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/homebrew/Caskroom/miniforge/base/envs/testcv/bin/python3.8 -m pip install --upgrade pip' command.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/_j/cr0dgwbj6jv5fsq9qw1sy_b40000gn/T/ipykernel_2352/1206227508.py in <module>
#       2
#       3 get_ipython().system('pip install yfinance')
# ----> 4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#       6
#
# ModuleNotFoundError: No module named 'pandas'
